# %%
import numpy as np
import pandas as pd

# %%
content = pd.read_csv('clementines-hse2018-part (1).csv')

# %%
content
# Out:
#    Label Scale  Weight  Width  Height  Sweet  Sour  Aroma  Seeds
# 0     S1   NaN    88.0  60.82   54.05    NaN   NaN    NaN    NaN
# 1     S2   NaN     NaN    NaN     NaN    NaN   NaN    NaN    NaN
# 2     S3   NaN    87.0   5.92    5.04    2.0   3.0    3.0    0.0
# 3     S4   NaN    76.0  58.08   42.88    1.0   2.0    2.0    1.0
# 4     S5   NaN    80.0  57.76   46.50    3.0   1.0    2.0    1.0
# ..   ...   ...     ...    ...     ...    ...   ...    ...    ...
# 68   G10     A    59.0  51.11   44.03    NaN   NaN    NaN    0.0
# 69   G11     A    62.0  51.54   44.34    NaN   NaN    NaN    0.0
# 70   G12     A    73.0  53.30   47.36    NaN   NaN    NaN    0.0
# 71   G13     A    64.0  50.71   43.50    NaN   NaN    NaN    0.0
# 72   G14     A    69.0  54.66   49.85    NaN   NaN    NaN    0.0
#
# [73 rows x 9 columns]

# %%
single_column = content[['Width', 'Weight']]

# %%
single_column
# Out:
#     Width  Weight
# 0   60.82    88.0
# 1     NaN     NaN
# 2    5.92    87.0
# 3   58.08    76.0
# 4   57.76    80.0
# ..    ...     ...
# 68  51.11    59.0
# 69  51.54    62.0
# 70  53.30    73.0
# 71  50.71    64.0
# 72  54.66    69.0
#
# [73 rows x 2 columns]

# %%
content.head(73)
# Out:
#    Label Scale  Weight  Width  Height  Sweet  Sour  Aroma  Seeds
# 0     S1   NaN    88.0  60.82   54.05    NaN   NaN    NaN    NaN
# 1     S2   NaN     NaN    NaN     NaN    NaN   NaN    NaN    NaN
# 2     S3   NaN    87.0   5.92    5.04    2.0   3.0    3.0    0.0
# 3     S4   NaN    76.0  58.08   42.88    1.0   2.0    2.0    1.0
# 4     S5   NaN    80.0  57.76   46.50    3.0   1.0    2.0    1.0
# ..   ...   ...     ...    ...     ...    ...   ...    ...    ...
# 68   G10     A    59.0  51.11   44.03    NaN   NaN    NaN    0.0
# 69   G11     A    62.0  51.54   44.34    NaN   NaN    NaN    0.0
# 70   G12     A    73.0  53.30   47.36    NaN   NaN    NaN    0.0
# 71   G13     A    64.0  50.71   43.50    NaN   NaN    NaN    0.0
# 72   G14     A    69.0  54.66   49.85    NaN   NaN    NaN    0.0
#
# [73 rows x 9 columns]

# %%
content.loc[2:4, :]
# Out:
#   Label Scale  Weight  Width  Height  Sweet  Sour  Aroma  Seeds
# 2    S3   NaN    87.0   5.92    5.04    2.0   3.0    3.0    0.0
# 3    S4   NaN    76.0  58.08   42.88    1.0   2.0    2.0    1.0
# 4    S5   NaN    80.0  57.76   46.50    3.0   1.0    2.0    1.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
content.head(73)
# Out:
#    Label Scale  Weight  Width  Height  Sweet  Sour  Aroma  Seeds
# 0     S1   NaN    88.0  60.82   54.05    NaN   NaN    NaN    NaN
# 1     S2   NaN     NaN    NaN     NaN    NaN   NaN    NaN    NaN
# 2     S3   NaN    87.0   5.92    5.04    2.0   3.0    3.0    0.0
# 3     S4   NaN    76.0  58.08   42.88    1.0   2.0    2.0    1.0
# 4     S5   NaN    80.0  57.76   46.50    3.0   1.0    2.0    1.0
# ..   ...   ...     ...    ...     ...    ...   ...    ...    ...
# 68   G10     A    59.0  51.11   44.03    NaN   NaN    NaN    0.0
# 69   G11     A    62.0  51.54   44.34    NaN   NaN    NaN    0.0
# 70   G12     A    73.0  53.30   47.36    NaN   NaN    NaN    0.0
# 71   G13     A    64.0  50.71   43.50    NaN   NaN    NaN    0.0
# 72   G14     A    69.0  54.66   49.85    NaN   NaN    NaN    0.0
#
# [73 rows x 9 columns]

# %%
plt.plot(content.Label, content.Width)
plt.xlabel('Label')
plt.ylabel('Width')
plt.show()

# %%
type(content)
# Out:
# pandas.core.frame.DataFrame

# %%
content.head()
# Out:
#   Label Scale  Weight  Width  Height  Sweet  Sour  Aroma  Seeds
# 0    S1   NaN    88.0  60.82   54.05    NaN   NaN    NaN    NaN
# 1    S2   NaN     NaN    NaN     NaN    NaN   NaN    NaN    NaN
# 2    S3   NaN    87.0   5.92    5.04    2.0   3.0    3.0    0.0
# 3    S4   NaN    76.0  58.08   42.88    1.0   2.0    2.0    1.0
# 4    S5   NaN    80.0  57.76   46.50    3.0   1.0    2.0    1.0

# %%
content.loc[3, 'Weight']
# Out:
# 76.0

# %%
content.loc[[3,7], ['Weight', 'Height']]
# Out:
#    Weight  Height
# 3    76.0   42.88
# 7    86.0   57.14

# %%
content.loc[3:7, ['Weight', 'Height']]
# Out:
#    Weight  Height
# 3    76.0   42.88
# 4    80.0   46.50
# 5    81.0   49.95
# 6    99.0   55.10
# 7    86.0   57.14

# %%
content.loc[3:7, :]
# Out:
#   Label Scale  Weight  Width  Height  Sweet  Sour  Aroma  Seeds
# 3    S4   NaN    76.0  58.08   42.88    1.0   2.0    2.0    1.0
# 4    S5   NaN    80.0  57.76   46.50    3.0   1.0    2.0    1.0
# 5    S6   NaN    81.0  54.77   49.95    2.0   1.0    2.0    1.0
# 6    S7   NaN    99.0  63.40   55.10    2.0   1.0    3.0    0.0
# 7    S8   NaN    86.0  56.58   57.14    1.0   3.0    2.0    1.0

# %%
content.iloc[3:7, :]
# Out:
#   Label Scale  Weight  Width  Height  Sweet  Sour  Aroma  Seeds
# 3    S4   NaN    76.0  58.08   42.88    1.0   2.0    2.0    1.0
# 4    S5   NaN    80.0  57.76   46.50    3.0   1.0    2.0    1.0
# 5    S6   NaN    81.0  54.77   49.95    2.0   1.0    2.0    1.0
# 6    S7   NaN    99.0  63.40   55.10    2.0   1.0    3.0    0.0

# %%
content.iloc[3:7, 2:9]
# Out:
#    Weight  Width  Height  Sweet  Sour  Aroma  Seeds
# 3    76.0  58.08   42.88    1.0   2.0    2.0    1.0
# 4    80.0  57.76   46.50    3.0   1.0    2.0    1.0
# 5    81.0  54.77   49.95    2.0   1.0    2.0    1.0
# 6    99.0  63.40   55.10    2.0   1.0    3.0    0.0

# %%
content = content.iloc[3:7, 2:9]

# %%
content.head(73)
# Out:
#    Weight  Width  Height  Sweet  Sour  Aroma  Seeds
# 3    76.0  58.08   42.88    1.0   2.0    2.0    1.0
# 4    80.0  57.76   46.50    3.0   1.0    2.0    1.0
# 5    81.0  54.77   49.95    2.0   1.0    2.0    1.0
# 6    99.0  63.40   55.10    2.0   1.0    3.0    0.0

# %%
content.describe()
# Out:
#           Weight      Width     Height     Sweet  Sour  Aroma  Seeds
# count   4.000000   4.000000   4.000000  4.000000  4.00   4.00   4.00
# mean   84.000000  58.502500  48.607500  2.000000  1.25   2.25   0.75
# std    10.230673   3.589191   5.202585  0.816497  0.50   0.50   0.50
# min    76.000000  54.770000  42.880000  1.000000  1.00   2.00   0.00
# 25%    79.000000  57.012500  45.595000  1.750000  1.00   2.00   0.75
# 50%    80.500000  57.920000  48.225000  2.000000  1.00   2.00   1.00
# 75%    85.500000  59.410000  51.237500  2.250000  1.25   2.25   1.00
# max    99.000000  63.400000  55.100000  3.000000  2.00   3.00   1.00
